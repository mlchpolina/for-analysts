# %% [markdown]
# ![38410A0B-334F-4102-9989-5313D9326A01.jpeg](data:image/jpeg;base64,...)

# %%
import timeit
import numpy as np 

n=int(input())

def Task1(n):
    z = np.zeros(n, dtype=float)

def Task2(n):
    z = np.array([0 for __ in range(n)], dtype=float)

def Task1NoNumPy(n):
    z = [0]*n

if __name__ == '__main__':

  start_time = timeit.default_timer()
  Task1(n)
  time_1 = timeit.default_timer() - start_time

  start_time = timeit.default_timer()
  Task2(n)
  time_2 = timeit.default_timer() - start_time

# %%
print(f'время {time_1}') 
print(f'время {time_2}')

# %%
import numpy as np
n=int(input())
Z=[0]
print((Z)*n)
