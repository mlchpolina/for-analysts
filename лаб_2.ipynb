# %% [markdown]
# 2.1.4. Напишите программу на Python, чтобы нарисовать линейные графики финансовых данных Alphabet Inc. в период с 3 октября 2016 года по 7 октября 2016 года.
# Пример финансовых данных (fdata.csv):
# Дата, Open, High, Low, Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017
# Фрагмент кода дает вывод, показанный на следующем снимке экрана:
# ![2021-02-25_20-12-54.png](data:image/png;base64,...)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(

name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d1d9bec9-025d-4a47-8ea5-f6017302d498" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1d9bec9-025d-4a47-8ea5-f6017302d498">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fdata.csv to fdata.csv
# User uploaded file "fdata.csv" with length 273 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('fdata.csv', sep=',' , parse_dates = True, index_col = 0)
df.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 2.2.5. Напишите программирование на Python, чтобы отобразить гистограмму популярности языков программирования. Прикрепите текстовую метку над каждой строкой, отображающую ее популярность (значение с плавающей запятой).
# Пример данных:
# Языки программирования: Java, Python, PHP, JavaScript, C #, C ++
# Популярность: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# Фрагмент кода дает вывод, показанный на следующем снимке экрана:
#
# ![2021-02-25_20-08-57.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Java', 'Python', 'PHP', 'JavaScript', 'C#','C++']
level = [22.2, 17.6, 8.8, 8, 7.7,6.7]
ax.bar(langs, level)
ax.set_title("Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago")
ax.set_xlabel('Languages')
ax.set_ylabel('Popularity')
x_pos = [i for i, _ in enumerate(x)]
plt.xticks(x_pos, x)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# 2.3.1. Напишите Python для программирования, чтобы создать круговую диаграмму популярности языков программирования.
# Пример данных:
# Языки программирования: Java, Python, PHP, JavaScript, C #, C ++
# Популярность: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# Фрагмент кода дает вывод, показанный на следующем снимке экрана:
#     ![2021-02-25_20-19-17.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Java', 'Python', 'PHP', 'JavaScript', 'C#','C++']
students = [22.2, 17.6, 8.8,8, 7.7, 6.7]
ax.pie(students, explode=explode, labels=langs ,autopct='%1.1f%%', shadow=True, startangle=140)
ax.axis('equal')
plt.show()

# %% [markdown]
# 2.4.3. Напишите программу на Python для построения точечной диаграммы с использованием случайных распределений для создания шаров разных размеров.
# Фрагмент кода дает вывод, показанный на следующем снимке экрана:
#
# ![2021-02-25_20-22-39.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
x = np.random.rand(30)
y = np.random.rand(30)
z = np.random.rand(30)
colors = np.random.rand(30) 
plt.scatter(x, y, s = z*300,c=colors)
plt.xlabel(' X')
plt.ylabel(' Y')
plt.show()

# %% [markdown]
# 2.5.2 Провести анализ датасетов с помощью библиотеки Matplotlib, Pyplot
# 1.	Построить несколько графиков на одном поле
# 2.	Построить диаграммы для категориальных данных
# 3.	Построить столбчатые и круговые диаграммы
# 4.	Реализовать цветовую сетку данных
# 5.	Построить 3D график.
#
#
#
# 16.	World Happiness Report up to 2020 - Bliss scored agreeing to financial, social, etc.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-1371f6e4-c332-47c2-a217-9ab336461b1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1371f6e4-c332-47c2-a217-9ab336461b1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2016[1].csv to 2016[1] (3).csv
# User uploaded file "2016[1].csv" with length 17132 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('2016[1].csv', sep=',' , parse_dates = True, index_col = 0)
df.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9c0cfc87-09b8-4da8-95ea-2e4e2d0a078f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c0cfc87-09b8-4da8-95ea-2e4e2d0a078f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2016[1].csv to 2016[1] (4).csv
# User uploaded file "2016[1].csv" with length 17132 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("2016[1].csv", sep=',' , parse_dates = True, index_col = 0)
point=['Happiness Rank','Happiness Score','Economy (GDP per Capita)']
sum_m = df["Happiness Rank"].sum()
print(sum_m)
sum_f = df["Happiness Score"].sum()
print(sum_f)
sum_v = df["Economy (GDP per Capita)"].sum()
print(sum_v)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
happy = [sum_m, sum_f,sum_v]
ax.pie(happy,labels = point, autopct = '%1.2f%%', wedgeprops={'lw':1,'edgecolor':"k"})
ax.set_title("счастье")
plt.show()
# Out:
# 12400
# 845.0029999999999
# 149.75913

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-08c4c148-a9bb-4c62-af01-c592070b4881" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08c4c148-a9bb-4c62-af01-c592070b4881">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2016[1].csv to 2016[1] (5).csv
# User uploaded file "2016[1].csv" with length 17132 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("2016[1].csv", sep = ',', parse_dates=True)
sum_m = df["Family"].sum()
print(sum_m)
sum_f = df["Freedom"].sum()
print(sum_f)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
happy = [sum_m, sum_f]
point = ['Family', 'Freedom']
ax.bar(point, happy, color = 'y')
ax.set_title("счастье реально")
ax.set_ylabel('шкала счастья')
plt.show()
# Out:
# 124.59851
# 58.24604000000001
